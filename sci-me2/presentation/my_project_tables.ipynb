# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages
from IPython.core.display import HTML





# Patients' information


advanced_tumor = [False, False, False, True, False, False, False, False, False, False, False, False, False, False,
                  False, False, False, False, False, False, False, False, False, False, False, False, False, False,
                  False, False, False, False, False, False, False, False, False, True, False, False, False, False,
                  False, False, False, False, False, False, False, False, False, True, False, False, False, False,
                  False, False, False, False, False, False, False, False, False, False, False, False, False, False,
                  False, True, False, False, False, False, False, False, False, False, False, False, False, False,
                  False, False, False, False, False, False, False, True, False, False, False, False, True, False, True, False]


differentiation = ['High', 'High', 'Moderate', 'High', 'Moderate', 'Low', 'Moderate', 'High', 'Moderate', 'Low', 'Low',
                   'High', 'Low', 'Moderate', 'Low', 'Moderate', 'Low', 'Low', 'Low', 'High', 'Moderate', 'Moderate',
                   'Moderate', 'Low', 'High', 'High', 'Moderate', 'High', 'High', 'High', 'High', 'High', 'Moderate', 'High',
                   'High', 'High', 'High', 'Moderate', 'Moderate', 'Moderate', 'High', 'High', 'Low', 'High', 'Low', 'High',
                   'Low', 'Low', 'Moderate', 'Low', 'Moderate', 'Moderate', 'High', 'High', 'Low', 'Moderate', 'Moderate',
                   'Moderate', 'High', 'Moderate', 'High', 'High', 'High', 'Moderate', 'High', 'Moderate', 'High', 'High',
                   'High', 'Moderate', 'Low', 'High', 'Moderate', 'High', 'High', 'Low', 'High', 'Moderate', 'Moderate',
                   'Low', 'Moderate', 'Moderate', 'High', 'High', 'Moderate', 'High', 'High', 'High', 'High', 'Low',
                   'Moderate', 'Low', 'High', 'High', 'High', 'Moderate', 'Low', 'Moderate', 'High', 'Low']



medical_history = ['Yes', 'Yes', 'No', 'Yes', 'No', 'No', 'Yes', 'No', 'No', 'Yes', 'No', 'No', 'Yes', 'No', 'No', 'Yes', 'No',
 'Yes', 'No', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', 'Yes', 'No', 'No', 'No', 'Yes',
 'Yes', 'No', 'No', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'No', 'Yes', 'No', 'No', 'Yes',
 'No', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'No', 'No', 'Yes', 'No', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'No',
 'No', 'Yes', 'Yes', 'No', 'No', 'No', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No', 'No', 'Yes', 'No',
 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Yes', 'Yes']



ibd= [False, False, False, False, False, False, False, False, False, False, False, False, False, False, False,
      False, False, False, False, False, False, False, False, False, False, True, False, False, False, False,
      False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False,
      False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False,
      False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False,
      False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False,
      False, False, False, False, False, True]


chemotherapy = [False, False, False, False, False, False, True, False, False, False, False, False, False, True, False,
                False, False, False, False, False, False, True, False, False, True, False, False, False, False, False,
                True, False, False, False, False, False, True, False, False, False, True, False, True, True, False,
                False, True, False, False, False, False, False, True, False, False, False, True, True, False, False,
                False, False, False, False, False, False, False, False, False, True, False, False, False, False, False,
                True, True, True, False, False, True, False, False, False, False, False, False, False, False, False,
                False, True, False, False, True, False, False, False, False, False]


metastasis = [False, True, False, False, False, False, False, True, False, False, True, True, False, False, False,
              False, False, True, False, False, False, False, True, False, False, False, False, True, False, True,
              False, False, False, False, True, True, True, False, True, False, False, True, False, False, False,
              True, False, False, True, False, False, False, False, False, False, True, False, False, False, True,
              False, True, False, False, False, False, False, False, False, False, False, False, False, False, False,
              False, False, False, True, False, False, True, True, False, False, True, False, False, False, True,
              True, False, False, False, False, False, False, False, False, False]


patient_VS = ['alive', 'deceased', 'alive', 'deceased', 'alive', 'alive', 'alive', 'alive', 'alive', 'alive',
              'alive', 'alive', 'alive', 'alive', 'alive', 'alive', 'alive', 'alive', 'alive', 'alive', 'alive',
              'alive', 'deceased', 'alive', 'alive', 'alive', 'alive', 'alive', 'alive', 'deceased', 'alive',
              'alive', 'alive', 'alive', 'alive', 'alive', 'alive', 'deceased', 'alive', 'alive', 'alive', 'deceased',
              'alive', 'alive', 'alive', 'alive', 'alive', 'alive', 'alive', 'alive', 'alive', 'alive', 'alive',
              'alive', 'alive', 'alive', 'alive', 'alive', 'alive', 'alive', 'alive', 'alive', 'alive', 'alive', 
              'deceased', 'alive', 'alive', 'alive', 'alive', 'alive', 'alive', 'alive', 'alive', 'alive', 'alive',
              'deceased', 'alive', 'alive', 'alive', 'deceased', 'alive', 'alive', 'alive', 'alive', 'alive', 'alive',
              'alive', 'alive', 'alive', 'alive', 'alive', 'alive', 'alive', 'alive', 'alive', 'deceased', 'alive',
              'alive', 'deceased', 'alive']


tumor_loc = ['rectum & sigmoid', 'colon', 'rectum & sigmoid', 'rectum & sigmoid', 'rectum & sigmoid', 'rectum & sigmoid', 'rectum & sigmoid',
             'colon', 'rectum & sigmoid', 'colon', 'colon', 'rectum & sigmoid', 'rectum & sigmoid', 'colon', 'colon',
             'rectum & sigmoid', 'rectum & sigmoid', 'rectum & sigmoid', 'rectum & sigmoid', 'rectum & sigmoid',
             'rectum & sigmoid', 'rectum & sigmoid', 'colon', 'rectum & sigmoid', 'rectum & sigmoid', 'colon',
             'rectum & sigmoid', 'colon', 'rectum & sigmoid', 'rectum & sigmoid', 'rectum & sigmoid', 'rectum & sigmoid',
             'rectum & sigmoid', 'colon', 'colon', 'rectum & sigmoid', 'rectum & sigmoid', 'rectum & sigmoid',
             'rectum & sigmoid', 'colon', 'colon', 'colon', 'rectum & sigmoid', 'rectum & sigmoid', 'colon', 'colon',
             'colon', 'colon', 'colon', 'rectum & sigmoid', 'rectum & sigmoid', 'rectum & sigmoid', 'rectum & sigmoid',
             'rectum & sigmoid', 'rectum & sigmoid', 'rectum & sigmoid', 'colon', 'colon', 'rectum & sigmoid',
             'colon', 'rectum & sigmoid', 'rectum & sigmoid', 'colon', 'rectum & sigmoid', 'rectum & sigmoid', 'rectum & sigmoid',
             'rectum & sigmoid', 'colon', 'rectum & sigmoid', 'colon', 'rectum & sigmoid', 'colon', 'colon', 'colon',
             'rectum & sigmoid', 'rectum & sigmoid', 'rectum & sigmoid', 'rectum & sigmoid', 'rectum & sigmoid', 'colon',
             'colon', 'colon', 'rectum & sigmoid', 'rectum & sigmoid', 'colon', 'colon', 'rectum & sigmoid', 
             'rectum & sigmoid', 'rectum & sigmoid', 'rectum & sigmoid', 'rectum & sigmoid', 'rectum & sigmoid',
             'colon', 'rectum & sigmoid', 'rectum & sigmoid', 'rectum & sigmoid', 'rectum & sigmoid', 'rectum & sigmoid',
             'rectum & sigmoid', 'colon']



df = pd.DataFrame({'ID':[i for i in range(1,101)],'Gender': ['M' if i < 59 else 'F' for i in range(100)],
                'Age': ['> 50' if i > 58 and i < 65 else '< 50' if i >= 14 else '> 50' for i in range(100)],
                  'Diagnostic Age': ['< 50' if i>59 and i<64 else '> 50' if i>=11 else '< 50' for i in range(100)],
                  'Advanced Tumor':advanced_tumor, 'Differentiation': differentiation,'Medical History':medical_history,
                   'IBD':ibd, 'Chemotherapy': chemotherapy, 'Metastasis': metastasis, 'Patient Vital Status': patient_VS,
                   'Tumor Location': tumor_loc
                  })


pd.set_option('display.max_rows', None)


fig, ax =plt.subplots(figsize=(24,8))
ax.axis('tight')
ax.axis('off')
the_table = ax.table(cellText=df.values,colLabels=df.columns,loc='center')
pp = PdfPages("foo.pdf")
pp.savefig(fig, bbox_inches='tight')
pp.close()








# Experiments' result




df1 = pd.DataFrame([[1,'gender','m',52,10.3,58,0.893],[2,'gender','f',38,4,42,0.893],[3,'disease stage','1 & 2',43,5,48,'_'],
                   [4,'disease stage','3 & 4',47,5,52,'_'],[5,'metastasis',True,18,6,24,0.0005],[6,'metastasis','liver',14,1,15,0.0005],
                   [7,'metastasis','other organs',4,5,9,0.0005],[8,'metastasis',False,72,4,76,0.0005],[9,'patient vital status','alive',82,7,89,0.043],
                   [10,'patient vital status','deceased',8,3,11,0.043],[11,'tumor location','rectum & sigmoid',28,7,35,0.014],[12,'tumor location','colon',62,3,65,0.014],
                   [13,'diferentiation','low & moderate',47,8,55,0.094],[14,'differentiation','high',43,2,45,0.094],[15,'advanced tumor',True,5,2,7,0.089],
                   [16,'advanced tumor',False,85,8,93,0.089],[17,'age','> 50',17,3,20,0.405],[18,'age','< 50',73,7,80,0.405],
                   [19,'diagnostic age','< 50',78,7,85,0.161],[20,'diagnostic age','> 50',12,3,15,0.161]],
                  columns=['ID','Investigated Items','Variables','HER2 +','HER2 -','Total','P-value'])


fig, ax =plt.subplots(figsize=(8,24))
ax.axis('tight')
ax.axis('off')
the_table = ax.table(cellText=df.values,colLabels=df.columns,loc='center',cellLoc='center',
                     rowLoc='center',fontsize=24, cellColours=[['lightgray']*len(df.columns)]*len(df))
pp = PdfPages("diagnostic.pdf")
pp.savefig(fig, bbox_inches='tight')
pp.close()





# PCR Materials




from matplotlib.backends.backend_pdf import PdfPages
fig, ax =plt.subplots(figsize=(6,18))
ax.axis('tight')
ax.axis('off')
df2 = pd.DataFrame({'ID':[1,2,3,4,5,6,7,8],'Materials':['DDW','10x buffer','dNTP mix 10 mM','MgCl2 50 mM','Forward primer','Revers primer','Taq polymerase','DNA pemplate'],
                   'Volume':['11.25 ul','2.5 ul','0.5 ul','.75 ul','1 ul','1 ul','0.25 ul','2 ul']})

styles = [dict(selector="th", props=[("border-collapse", "collapse"), ("border", "1px solid #ddd"), ("padding", "5px 10px")]),
          dict(selector="td", props=[("border-collapse", "collapse"), ("border", "1px solid #ddd"), ("padding", "5px 10px")])]

styled_table = df2.style.set_table_styles(styles)


HTML(styled_table.to_html())


the_table = ax.table(cellText=df2.values,colLabels=df2.columns,loc='center',cellLoc='center',
                      rowLoc='center',fontsize=1)
pp = PdfPages("pcr_materials.pdf")
pp.savefig(fig, bbox_inches='tight')
pp.close()





# Buffer 



df3 = pd.DataFrame({'Materials':["Tris alkaline powder","Boric acid powder","EDTA(Titriplex) powder","Deionized water"],
                   'Quantity': ['108 g','55 g','7.4 g', ' up to one liter']})

fig, ax =plt.subplots(figsize=(4,4))
ax.axis('tight')
ax.axis('off')

styles3 = [dict(selector="th", props=[("border-collapse", "collapse"), ("border", "0.1px solid #ddd"), ("padding", "5px 10px")]),
          dict(selector="td", props=[("border-collapse", "collapse"), ("border", "0.1px solid #ddd"), ("padding", "5px 10px")])]

styled_table = df3.style.set_table_styles(styles3)


HTML(styled_table.to_html())


the_table = ax.table(cellText=df3.values,colLabels=df3.columns,loc='center',cellLoc='center',
                      rowLoc='center',fontsize=1)
pp = PdfPages("buffer.pdf")
pp.savefig(fig, bbox_inches='tight')
pp.close()




# guide_color



df4 = pd.DataFrame({'Materials':["xylene cyanol powder","bromophenol blue powder","glycerol","deionized distilled water"],
                   'Quantity':['0.025 g','0.025 g','3.5 ml','up to 10 ml']})

fig, ax =plt.subplots(figsize=(6,6))
ax.axis('tight')
ax.axis('off')
styles4 = [dict(selector="th", props=[("border-collapse", "collapse"), ("border", "0.1px solid #ddd"), ("padding", "5px 10px")]),
          dict(selector="td", props=[("border-collapse", "collapse"), ("border", "0.1px solid #ddd"), ("padding", "5px 10px")])]

styled_table4 = df4.style.set_table_styles(styles4)


HTML(styled_table4.to_html())


the_table = ax.table(cellText=df4.values,colLabels=df4.columns,loc='center',cellLoc='center',
                      rowLoc='center',fontsize=1)
pp = PdfPages("color.pdf")
pp.savefig(fig, bbox_inches='tight')
pp.close()
